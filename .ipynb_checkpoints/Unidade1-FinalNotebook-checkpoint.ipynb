# %% [markdown]
# # Estudo em dados sobre pesquisa da UFRN
#
# Um dos parâmetros para medir a qualidade de uma instituição de ensino, é o quanto ela investe em pesquisa e desenvolvimento, incentivando seus alunos a terem familiaridade com trabalhos científicos ainda na graduação. Desse modo, esse trabalho tem por objetivo fazer uma análise sobre os dados dos bolsistas de iniciação científica, pesquisadores e projetos de pesquisa da UFRN e apresentar, de forma clara, algumas informações sobre eles.
#
# Trabalho desenvolvido com base de dados abertos da UFRN
# *http://dados.ufrn.br/

# %% [markdown]
# ## 1. Médias, medianas, modas e desvio padrão

# %%
# Importar o Pandas
import pandas as pd

# Importar os dados de bolsistas-de-iniciacao-cientifica.csv
data = pd.read_csv("bolsistas-de-iniciacao-cientifica.csv", encoding = 'utf-8', sep = None, engine = 'python')

# %%
data.head()
# Out:
#     matricula                      discente  \
# 0   200504593  ABDON SILVA RIBEIRO DA CUNHA
# 1   200504593  ABDON SILVA RIBEIRO DA CUNHA
# 2   200504593  ABDON SILVA RIBEIRO DA CUNHA
# 3   200504593  ABDON SILVA RIBEIRO DA CUNHA
# 4  2011049415       ABEL LUIS DA SILVA NETO
#
#                                               titulo codigo_projeto   ano  \
# 0  Motivos de Adesão e Filiação ao Trabalho Volun...   PVE3275-2009  2009
# 1  O agronegócio da carcinicultura no RN e a estr...    PVE334-2007  2007
# 2  Geração e disseminação da inovação na carcinic...   PVE2463-2008  2008
# 3  O agronegócio da carcinicultura no RN e a estr...    PVE334-2006  2006
# 4  Estudo de Antenas com Reflectarrays e suas Apl...   PVG6992-2013  2013
#
#                  orientador                   categoria tipo_de_bolsa  \
# 0  WASHINGTON JOSE DE SOUSA   Iniciação Científica (IC)         PIBIC
# 1             MARIANA BALDI   Iniciação Científica (IC)         PIBIC
# 2             MARIANA BALDI   Iniciação Científica (IC)         PIBIC
# 3             MARIANA BALDI   Iniciação Científica (IC)       PROPESQ
# 4  ADAILDO GOMES D ASSUNCAO  Iniciação Tecnológica (IT)         PIBIT
#
#                                    linha_pesquisa  \
# 0    Análise e Avaliação de Políticas Públicas;;;
# 1  Organizações e comportamento organizacional;;;
# 2     Organizações e comportamento organizacional
# 3  Organizações e comportamento organizacional;;;
# 4      ANTENAS, PROPAGAÇÃO E COMUNICAÇÕES SEM FIO
#
#                                        base_pesquisa       cota      inicio  \
# 0                                                NaN  2009-2010  2009-08-01
# 1  BASE DE ESTUDOS E PESQUISAS EM ESTRATÉGIAS E P...  2007-2008  2007-08-01
# 2  BASE DE ESTUDOS E PESQUISAS EM ESTRATÉGIAS E P...  2008-2009  2008-08-25
# 3  BASE DE ESTUDOS E PESQUISAS EM ESTRATÉGIAS E P...  2006-2007  2006-08-01
# 4                      GRUPO DE MICROONDAS E ANTENAS  2013-2014  2013-08-14
#
#                        fim                                            unidade  \
# 0      2009-12-25 00:00:00  DEPARTAMENTO DE CIÊNCIAS ADMINISTRATIVAS - DEP...
# 1      2008-07-31 00:00:00        CENTRO DE CIÊNCIAS SOCIAIS APLICADAS - CCSA
# 2  2008-11-06 13:35:24.877  DEPARTAMENTO DE CIÊNCIAS ADMINISTRATIVAS - DEP...
# 3      2007-07-31 00:00:00        CENTRO DE CIÊNCIAS SOCIAIS APLICADAS - CCSA
# 4      2014-06-26 00:00:00   DEPARTAMENTO DE ENGENHARIA DE COMUNICACOES - DCO
#
#                   status
# 0             FINALIZADO
# 1             FINALIZADO
# 2             FINALIZADO
# 3             FINALIZADO
# 4  PENDENTE DE RELATORIO

# %% [markdown]
# ### Tratamento dos dados

# %%
#Colunas da matriz de dados
data.columns.values.tolist()

##Colunas dispensáveis para esse projeto: discente, código projeto
# Out:
# ['matricula',
#  'discente',
#  'titulo',
#  'codigo_projeto',
#  'ano',
#  'orientador',
#  'categoria',
#  'tipo_de_bolsa',
#  'linha_pesquisa',
#  'base_pesquisa',
#  'cota',
#  'inicio',
#  'fim',
#  'unidade',
#  'status']

# %%
# Removendo-as...
data.drop(data.columns[1], axis=1, inplace=True)
data.drop(data.columns[2], axis=1, inplace=True)

# %%
#Número de entradas: 26473
data.info()
#Dados não obrigatórios: título, linha_pesquisa, base_pesquisa, cota, inicio, fim
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26473 entries, 0 to 26472
# Data columns (total 13 columns):
# matricula         26473 non-null int64
# titulo            26464 non-null object
# ano               26473 non-null int64
# orientador        26473 non-null object
# categoria         26473 non-null object
# tipo_de_bolsa     26473 non-null object
# linha_pesquisa    25610 non-null object
# base_pesquisa     22210 non-null object
# cota              26473 non-null object
# inicio            26468 non-null object
# fim               23323 non-null object
# unidade           26473 non-null object
# status            26473 non-null object
# dtypes: int64(2), object(11)
# memory usage: 2.6+ MB

# %%
#De modo a deixar a análise mais concisa, vamos fazer a análise dos dados dos ultimos 5 anos.

#Ordena dados por ano
data = data.sort_values(data.columns[2], ascending = True)
                 
#Dados dos últimos 5 anos
data_ultimosAnos = data[data['ano'] > 2012]

#Diminuição do número de dados: 11101 entradas
data_ultimosAnos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11101 entries, 1668 to 14065
# Data columns (total 13 columns):
# matricula         11101 non-null int64
# titulo            11101 non-null object
# ano               11101 non-null int64
# orientador        11101 non-null object
# categoria         11101 non-null object
# tipo_de_bolsa     11101 non-null object
# linha_pesquisa    10693 non-null object
# base_pesquisa     9121 non-null object
# cota              11101 non-null object
# inicio            11101 non-null object
# fim               8015 non-null object
# unidade           11101 non-null object
# status            11101 non-null object
# dtypes: int64(2), object(11)
# memory usage: 1.2+ MB

# %%
data_ultimosAnos.head()
# Out:
#         matricula                                             titulo   ano  \
# 1668   2013047581                          JOVENS TALENTOS - DIREITO  2013
# 968    2014018584  Efeito de fatores ambientais no envelhecimento...  2013
# 1639   2011043387  Fungos Micorrízicos Arbusculares em gradiente ...  2013
# 1688   2012910227  Transferindo informações sobre arquitetura ecl...  2013
# 18079  2012961638  A Atenção Primária e o direito à saúde em Nata...  2013
#
#                          orientador                  categoria  \
# 1668   ANA BEATRIZ FERREIRA REBELLO  Iniciação Científica (IC)
# 968          JOSE DANIEL DINIZ MELO  Iniciação Científica (IC)
# 1639               BRUNO TOMIO GOTO  Iniciação Científica (IC)
# 1688   EDJA BEZERRA FARIA TRIGUEIRO  Iniciação Científica (IC)
# 18079                 EDLA HOFFMANN  Iniciação Científica (IC)
#
#          tipo_de_bolsa                                     linha_pesquisa  \
# 1668   JOVENS TALENTOS                                                NaN
# 968              PIBIC                Materiais compósitos poliméricos;;;
# 1639           PROPESQ  Biodiversidade vegetal e funcionamento de ecos...
# 1688             REUNI               Morfologia e história da arquitetura
# 18079           NUPLAM    Estado, Sociedade, Políticas Sociais e Direitos
#
#                                            base_pesquisa  \
# 1668                                                 NaN
# 968                     MATERIAIS COMPÓSITOS E CERÂMICOS
# 1639   Ecologia de Populações e Comunidades Vegetais ...
# 1688             MORFOLOGIA E USOS DA ARQUITETURA - MUsA
# 18079  Grupo de Estudos e Pesquisas em Questão Social...
#
#                             cota      inicio                  fim  \
# 1668   JOVENS TALENTOS 2013-2014  2013-08-01  2014-07-31 00:00:00
# 968                    2014-2015  2014-08-09  2015-07-31 00:00:00
# 1639                        2014  2014-02-13  2015-07-31 00:00:00
# 1688                        2013  2013-03-04  2013-06-19 00:00:00
# 18079                       2014  2015-04-07  2015-07-31 00:00:00
#
#                                                  unidade      status
# 1668                  PRÓ-REITORIA DE PESQUISA - PROPESQ  FINALIZADO
# 968    DEPARTAMENTO DE ENGENHARIA DE MATERIAIS - DEPT...  FINALIZADO
# 1639       DEPARTAMENTO DE BOTÂNICA E ZOOLOGIA - DBEZ/CB  FINALIZADO
# 1688                DEPARTAMENTO DE ARQUITETURA - ARQ/CT  FINALIZADO
# 18079        DEPARTAMENTO DE SERVIÇO SOCIAL - DESSO/CCSA  FINALIZADO

# %% [markdown]
# ### Análise dos dados: Tipos de bolsa & Unidades mais contempladas com bolsistas
# Vamos verificar então a distribuição dos tipos de bolsas entre os alunos nos últimos 5 anos:

# %%
tipos_bolsa = data_ultimosAnos['tipo_de_bolsa'].reset_index()

#Novo dataframe com quantidade de cada bolsa
tipos_bolsa['count'] = 0
tipos_bolsa = pd.DataFrame(tipos_bolsa.groupby(['tipo_de_bolsa'])['count'].count()).reset_index()

tipos_bolsa = tipos_bolsa.sort_values(tipos_bolsa.columns[1], ascending = True).reset_index()
tipos_bolsa.drop(tipos_bolsa.columns[0], axis=1, inplace=True)

# %%
tipos_bolsa
# Out:
#              tipo_de_bolsa  count
# 0                   BALCÃO      1
# 1                      ECT      2
# 2              PPG/PROPESQ      2
# 3   Bolsas de IC/IT -PICME      5
# 4                  FUNTTEL      8
# 5              PIBITI CNPq     14
# 6            PIBIC AF CNPq     26
# 7                 PIBIC AF     41
# 8                    PIBIT     45
# 9                   NUPLAM     91
# 10             PIBITI UFRN    230
# 11         JOVENS TALENTOS    371
# 12                PIBIC-EM    399
# 13                   REUNI    486
# 14              PIBIC CNPq    871
# 15              PIBIC UFRN   1430
# 16                   PIBIC   1494
# 17                 PROPESQ   2332
# 18              VOLUNTÁRIO   3253

# %%
from bokeh.charts import Bar, output_notebook, show

p = Bar(tipos_bolsa, 'tipo_de_bolsa', values='count', title="Distribuição de bolsas da UFRN", legend = None )

p.xaxis.axis_label = 'Bolsas ofertadas'
p.yaxis.axis_label = 'Quantidade'

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aaff70f9-1c24-474d-aab5-c6c087331279">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6fb4df35-1fb0-41eb-bdc3-b7eadb841e42"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6fb4df35-1fb0-41eb-bdc3-b7eadb841e42");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6fb4df35-1fb0-41eb-bdc3-b7eadb841e42");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6fb4df35-1fb0-41eb-bdc3-b7eadb841e42' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"70f5ea59-d241-4866-84d2-5751b72369bd":{"roots":{"references":[{"attributes":{"data_source":{"id":"9c871ae0-69ee-4751-ae94-7ada5bfe38e3","type":"ColumnDataSource"},"glyph":{"id":"b33a0898-80bb-4827-ae55-7b0dd7556889","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"87596679-ea9d-453f-aa74-30f098536781","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"tipo_de_bolsa":"Bolsas de IC/IT -PICME"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[5.0],"label":[{"tipo_de_bolsa":"Bolsas de IC/IT -PICME"}],"line_alpha":[1.0],"line_color":["white"],"tipo_de_bolsa":["Bolsas de IC/IT -PICME"],"width":[0.8],"x":["Bolsas de IC/IT -PICME"],"y":[2.5]}},"id":"9c871ae0-69ee-4751-ae94-7ada5bfe38e3","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"db6ed03e-c357-49d4-9d1f-cc94126b3687","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"tipo_de_bolsa":"PIBIC-EM"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[399.0],"label":[{"tipo_de_bolsa":"PIBIC-EM"}],"line_alpha":[1.0],"line_color":["white"],"tipo_de_bolsa":["PIBIC-EM"],"width":[0.8],"x":["PIBIC-EM"],"y":[199.5]}},"id":"8c374be7-c088-4b5e-abfd-089711b1e54f","type":"ColumnDataSource"},{"attributes":{},"id":"9777eb3b-f8ac-4ee8-abff-4741c0d2d05f","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"3389ca79-c051-404e-9f2a-afdc7d9f2856","subtype":"Chart","type":"Plot"},"ticker":{"id":"9777eb3b-f8ac-4ee8-abff-4741c0d2d05f","type":"BasicTicker"}},"id":"4684708c-abf1-4a8d-8123-3a084e8a9ddb","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1531a05e-c9cc-4390-9e2e-1287a91ab976","type":"Rect"},{"attributes":{"data_source":{"id":"93333f6a-9e96-4a5a-aaf1-7e32d3ee3c45","type":"ColumnDataSource"},"glyph":{"id":"8b9c2ebf-0afb-4be0-ab5c-47f89a3da239","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a88d88bf-f6c8-4457-a5cf-5cccb0db35db","type":"GlyphRenderer"},{"attributes":{},"id":"dc0c440c-ae0c-41d8-a3cf-7394d4579bd6","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"013e3b35-d2d0-4186-a883-c37ba5a03ea8","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"tipo_de_bolsa":"PIBIC AF CNPq"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[26.0],"label":[{"tipo_de_bolsa":"PIBIC AF CNPq"}],"line_alpha":[1.0],"line_color":["white"],"tipo_de_bolsa":["PIBIC AF CNPq"],"width":[0.8],"x":["PIBIC AF CNPq"],"y":[13.0]}},"id":"93333f6a-9e96-4a5a-aaf1-7e32d3ee3c45","type":"ColumnDataSource"},{"attributes":{},"id":"15613e05-b546-4c8d-a785-6e877d70370e","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"795ad5ef-ff15-499f-9570-5830fb51c9ad","type":"ColumnDataSource"},"glyph":{"id":"013e3b35-d2d0-4186-a883-c37ba5a03ea8","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"60950b61-0916-427c-91b2-371521c9d940","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"tipo_de_bolsa":"PIBITI CNPq"}],"color":["#f22c40"],"fill_alpha ...

# %% [markdown]
# #### Análise preliminar
# $\qquad$ Pelo gráfico acima, pode-se perceber que a UF contava com 18 classificações de bolsas, fornecendo mais de 8000 bolsas ao
# longo desses 5 anos. Os tipos de bolsa remunerada que contemplam mais alunos são as do programa de Bolsas de Iniciação Científica da Pró-Reitoria de Pesquisa(PROPESQ-REUNI),Jovens Talentos e do programa Institucional de Bolsas de Iniciação Científica (PIBIC). As duas primeiras são ministradas diretamente pela UFRN, enquanto que as bolsas do PIBIC fazem parte do programa do Conselho Nacional de Desenvolvimento Científico e Tecnológico (CNPQ). <br/>
# $\qquad$ Podemos perceber ainda o grande número de voluntários ao longo desses 5 anos, o que pode indicar a grande demanda por bolsas e o grande interesse dos alunos em ingressarem a iniciação científica, o que só reforça a importância que esses programas de bolsas tem para a faculdade. <br/>
# $\qquad$ Vejamos agora um comparativo da distribuição das bolsas de pesquisa da UF ao longo dos últimos 17 anos e quais departamentos da instituição foram mais contemplados com bolsistas e voluntários.

# %% [markdown]
# ### Distribuição de bolsas ao longo dos anos:

# %%
bolsas = data.filter(['ano','tipo_de_bolsa'], axis=1).reset_index()
bolsas.drop(bolsas.columns[0], axis=1, inplace=True)

bolsas_por_ano = bolsas['tipo_de_bolsa'].groupby(bolsas['ano']).count()

#Distribuição das bolsas da UF ao longo dos anos, de 2001 até atualmente (2017)
bolsas_por_ano
# Out:
# ano
# 2001     662
# 2002     704
# 2003     735
# 2004     788
# 2005     789
# 2006     883
# 2007    1736
# 2008     850
# 2009    1853
# 2010    2349
# 2011    2000
# 2012    2023
# 2013    3595
# 2014    2707
# 2015    1865
# 2016    2009
# 2017     925
# Name: tipo_de_bolsa, dtype: int64

# %%
from bokeh.plotting import figure

p = figure(plot_width=500, plot_height=400)

anos = list(range(2001,2018))
valores = bolsas_por_ano.tolist()

# add a line renderer
p.line(anos, valores, line_width=2)

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d80fbddc-4d1e-4513-afb4-46170b1d41fb">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="341f1d68-9791-466c-a471-12e95bae55de"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("341f1d68-9791-466c-a471-12e95bae55de");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("341f1d68-9791-466c-a471-12e95bae55de");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '341f1d68-9791-466c-a471-12e95bae55de' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2fe6c573-ef5b-42c5-a408-005a78ceb975":{"roots":{"references":[{"attributes":{"overlay":{"id":"2e3957e1-b5cb-4da6-9364-fe278042fbe1","type":"BoxAnnotation"},"plot":{"id":"5fc50677-d50d-4d6f-a1d7-ae2c61da4755","subtype":"Figure","type":"Plot"}},"id":"8be3b8e5-da7d-49f6-9e1e-58d236537e32","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"5fc50677-d50d-4d6f-a1d7-ae2c61da4755","subtype":"Figure","type":"Plot"}},"id":"1ae72816-06c8-4f2c-8a45-263ac974ade3","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"e1203357-0494-41c5-90a1-d78a8531f14c","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"489f22aa-b1ba-4c47-a0de-c9b61f573b22","type":"PanTool"},{"id":"1ae72816-06c8-4f2c-8a45-263ac974ade3","type":"WheelZoomTool"},{"id":"8be3b8e5-da7d-49f6-9e1e-58d236537e32","type":"BoxZoomTool"},{"id":"aaf9321d-3080-4ec8-9e3c-ccf005550ded","type":"SaveTool"},{"id":"1075317c-5577-4539-83af-71daf85ad789","type":"ResetTool"},{"id":"7fb00641-6e42-4f0a-9227-94e4d4ea5f30","type":"HelpTool"}]},"id":"f8d6e648-b83d-442d-a664-fd5f10556802","type":"Toolbar"},{"attributes":{"plot":{"id":"5fc50677-d50d-4d6f-a1d7-ae2c61da4755","subtype":"Figure","type":"Plot"}},"id":"7fb00641-6e42-4f0a-9227-94e4d4ea5f30","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"5fc50677-d50d-4d6f-a1d7-ae2c61da4755","subtype":"Figure","type":"Plot"},"ticker":{"id":"f54ef16f-4c56-40d8-acbc-3ba08e27eed6","type":"BasicTicker"}},"id":"ea550049-a940-41cb-8db3-3cd4b084f2c8","type":"Grid"},{"attributes":{"data_source":{"id":"cfd16fd5-b9e1-431d-a279-0be62e6f7b99","type":"ColumnDataSource"},"glyph":{"id":"ad036127-b30b-4083-8de9-facc6d82ccb0","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e1203357-0494-41c5-90a1-d78a8531f14c","type":"Line"},"selection_glyph":null},"id":"73183a8a-adbd-437c-877b-ddfd69fd2b51","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"63ff574b-2167-4a06-9436-4c349e8f7637","type":"LinearAxis"}],"left":[{"id":"02b7dfa1-71f5-4604-8838-6615195d3ec5","type":"LinearAxis"}],"plot_height":400,"plot_width":500,"renderers":[{"id":"63ff574b-2167-4a06-9436-4c349e8f7637","type":"LinearAxis"},{"id":"9d44e6e7-7ddb-43a1-affc-9b8ef2f85633","type":"Grid"},{"id":"02b7dfa1-71f5-4604-8838-6615195d3ec5","type":"LinearAxis"},{"id":"ea550049-a940-41cb-8db3-3cd4b084f2c8","type":"Grid"},{"id":"2e3957e1-b5cb-4da6-9364-fe278042fbe1","type":"BoxAnnotation"},{"id":"73183a8a-adbd-437c-877b-ddfd69fd2b51","type":"GlyphRenderer"}],"title":{"id":"c9ac79e9-6d9b-4efe-900a-21a18c39807a","type":"Title"},"tool_events":{"id":"2de49d1d-be44-40b5-bb29-9362c74955f1","type":"ToolEvents"},"toolbar":{"id":"f8d6e648-b83d-442d-a664-fd5f10556802","type":"Toolbar"},"x_range":{"id":"43b120a8-bd8f-4fbd-84a7-9fec09c1b87f","type":"DataRange1d"},"y_range":{"id":"9d449341-0b1d-42e8-9ae3-0062a96fc26c","type":"DataRange1d"}},"id":"5fc50677-d50d-4d6f-a1d7-ae2c61da4755","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"ce0b8b37-edfd-4673-9c5e-418a8cdc920a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5fc50677-d50d-4d6f-a1d7-ae2c61da4755","subtype":"Figure","type":"Plot"}},"id":"aaf9321d-3080-4ec8-9e3c-ccf005550ded","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2e3957e1-b5cb-4da6-9364-fe278042fbe1","type":"BoxAnnotation"},{"attributes":{},"id":"b1646ff3-8de8-4381-b58f-3d7af58a4602","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"ad036127-b30b-4083-8de9-facc6d82ccb0","type":"L ...

# %%
media_valores = bolsas_por_ano.mean()
media_valores
# Out:
# 1557.235294117647

# %%
mediana_valores = bolsas_por_ano.median()
mediana_valores
# Out:
# 1736.0

# %%
moda_valores = bolsas_por_ano.mode()
moda_valores
# Out:
# 0      662
# 1      704
# 2      735
# 3      788
# 4      789
# 5      850
# 6      883
# 7      925
# 8     1736
# 9     1853
# 10    1865
# 11    2000
# 12    2009
# 13    2023
# 14    2349
# 15    2707
# 16    3595
# dtype: int64

# %%
desvio_padrao = bolsas_por_ano.std()
desvio_padrao
# Out:
# 854.1987861010284

# %% [markdown]
# $\qquad$ Pelo gráfico de linhas, temos uma boa noção de como se deu a distribuição de bolsas de pesquisa ao longo desses últimos 17 anos na UFRN. De modo geral, percebe-se que houve um gradativo aumento do número de oportunidades para os alunos desde 2001, começando com cerca de **662 contemplados, valor mínimo de bolsas **nessa distribuição, e tendo um ** valor máximo em 2013, com 3595 bolsas**. <br/>
# $\qquad$ Uma situação preocupante é que desde o seu máximo em 2013, o número de bolsas vem caindo gradativamente, até chegar ao menor valor de bolsistas e voluntários em 8 anos, com apenas 925 alunos ligados diretamente aos programas de bolsa da universidade até agora em 2017. Considerando que faltam pouco menos de 4 meses para o fim do período letivo, esse número não deve variar muito. <br/>
# $\qquad$ Quanto a dados estatísticos gerais, temos uma **média de bolsas por ano de 1557**. Valor não muito distante da **mediana, de 1736 bolsas**. A distribuição ainda tem um **desvio padrão de 854** e **não possui moda**.

# %% [markdown]
# ## 2. Números mínimos e máximos, de pelo menos duas variáveis, e suas amplitudes

# %% [markdown]
# ## 3. Pelo menos dois gráficos de Barras

# %% [markdown]
# ## 4. Pelo menos dois gráficos de Linhas

# %% [markdown]
# ## 5. Pelo menos dois gráficos Bloxplot

# %%
import numpy as np
import pandas as pd
from bokeh.charts import BoxPlot, output_notebook, show

df = pd.read_csv("projetos-de-pesquisa.csv", sep="\";\"")
df["ano"] = df["ano"].apply(pd.to_numeric, errors='coerce')

unidades = set()
unidadeInternalProjects = dict()
unidadeExternalProjects = dict()

def countProjectsByUnidade(row):
    if(row["tipo_projeto"] == "INTERNO"):
        unidadeInternalProjects[row["unidade"]] += 1
    elif(row["tipo_projeto"] == "EXTERNO"):
        unidadeExternalProjects[row["unidade"]] += 1
# Out:
# /home/pitagoras/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """

# %%
def projectsBoxplot(df, year=-2000, specificTypes=True):
    df = df[df.ano >= year]    
    for unidade in df.unidade.unique():
        unidades.add(unidade)
        unidadeInternalProjects[unidade] = 0
        unidadeExternalProjects[unidade] = 0
        
    df.apply(lambda row: countProjectsByUnidade(row), axis=1)
    
    rows = []
    for unidade in unidades:
        if(specificTypes):
            newRow = dict()
            newRow["unidade"] = unidade
            newRow["projType"] = "INTERNO"
            newRow["count"] = unidadeInternalProjects[unidade]
            rows.append(newRow)
            
            newRow = dict()
            newRow["unidade"] = unidade
            newRow["projType"] = "EXTERNO"
            newRow["count"] = unidadeExternalProjects[unidade]
            rows.append(newRow)
        else:
            newRow = dict()
            newRow["unidade"] = unidade
            newRow["projType"] = "TODOS"
            newRow["count"] = unidadeExternalProjects[unidade] + unidadeInternalProjects[unidade] 
            rows.append(newRow)
        
    unidadesDf = pd.DataFrame(rows, columns=["unidade", "projType",
                                             "count"])
    p = BoxPlot(unidadesDf, values='count', label="projType", color="projType",
                whisker_color='goldenrod', title="Projetos em Unidades da UFRN")
    output_notebook()
    show(p)

# %%
projectsBoxplot(df, year=2015, specificTypes=False)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="333970dd-0223-4ead-9223-271b52cbabb2">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7d3c69e0-d2b7-4fa7-aa09-5a713c3a305f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7d3c69e0-d2b7-4fa7-aa09-5a713c3a305f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7d3c69e0-d2b7-4fa7-aa09-5a713c3a305f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7d3c69e0-d2b7-4fa7-aa09-5a713c3a305f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2c3945d9-ee58-45f8-bd8c-15d0ad5f711e":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e7f72f2f-5149-4d05-88c1-121537337ce0","type":"PanTool"},{"id":"c020da14-43e4-4e52-818a-a3ce77bfd5ff","type":"WheelZoomTool"},{"id":"bf38a03b-3554-4c60-864e-04a1e44b3fe1","type":"BoxZoomTool"},{"id":"b03fb480-6623-4124-b4b5-f3dea2cb69ce","type":"SaveTool"},{"id":"159d4ba3-a1b1-461d-a291-70fb787edc51","type":"ResetTool"},{"id":"ed090dc9-c46b-42b6-bc2a-aac9624b077a","type":"HelpTool"}]},"id":"e13caa8b-ac1f-49a3-b8f0-bdb1ab2d69d0","type":"Toolbar"},{"attributes":{"plot":{"id":"17751007-c117-4bf8-95b3-500827ce4376","subtype":"Chart","type":"Plot"}},"id":"b03fb480-6623-4124-b4b5-f3dea2cb69ce","type":"SaveTool"},{"attributes":{"overlay":{"id":"a24164ad-2229-4a95-b170-83d7e32824a7","type":"BoxAnnotation"},"plot":{"id":"17751007-c117-4bf8-95b3-500827ce4376","subtype":"Chart","type":"Plot"}},"id":"bf38a03b-3554-4c60-864e-04a1e44b3fe1","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"17751007-c117-4bf8-95b3-500827ce4376","subtype":"Chart","type":"Plot"}},"id":"e7f72f2f-5149-4d05-88c1-121537337ce0","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"projType":"TODOS"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[6.0],"label":[{"projType":"TODOS"}],"line_alpha":[1.0],"line_color":["black"],"projType":["TODOS"],"width":[0.8],"x":["TODOS"],"y":[5.0]}},"id":"81789a28-647c-41c5-846a-d07c7bdb740d","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"Projetos em Unidades da UFRN"},"id":"f244634d-991c-4cac-9815-a6133a8760f4","type":"Title"},{"attributes":{"callback":null,"end":101.9},"id":"44b73c72-bf31-48f2-8635-89eb3fc8f8b2","type":"Range1d"},{"attributes":{"plot":{"id":"17751007-c117-4bf8-95b3-500827ce4376","subtype":"Chart","type":"Plot"}},"id":"ed090dc9-c46b-42b6-bc2a-aac9624b077a","type":"HelpTool"},{"attributes":{"plot":{"id":"17751007-c117-4bf8-95b3-500827ce4376","subtype":"Chart","type":"Plot"}},"id":"159d4ba3-a1b1-461d-a291-70fb787edc51","type":"ResetTool"},{"attributes":{"plot":{"id":"17751007-c117-4bf8-95b3-500827ce4376","subtype":"Chart","type":"Plot"}},"id":"c020da14-43e4-4e52-818a-a3ce77bfd5ff","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"projType":"TODOS"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[11.0],"label":[{"projType":"TODOS"}],"line_alpha":[1.0],"line_color":["black"],"projType":["TODOS"],"width":[0.8],"x":["TODOS"],"y":[13.5]}},"id":"9719fefb-4502-405b-b00b-bda683c38fe2","type":"ColumnDataSource"},{"attributes":{"label":{"value":"TODOS"},"renderers":[{"id":"f847f15b-ef8b-440c-9024-4d63fd11ed61","type":"GlyphRenderer"},{"id":"30d5fc55-5e35-46de-b548-64db9816e8b9","type":"GlyphRenderer"},{"id":"44e49c7a-baa9-476e-8ed0-f2077d4e676f","type":"GlyphRenderer"},{"id":"8f44ba02-7ce8-4624-a28d-0af5dda1a487","type":"GlyphRenderer"}]},"id":"14a4da3f-73a5-4557-a5c6-aa2ad58ee46d","type":"LegendItem"},{"attributes":{"data_source":{"id":"81789a28-647c-41c5-846a-d07c7bdb740d","type":"ColumnDataSource"},"glyph":{"id":"c0d9fe39-5cea-49ad-8ea0-22567e35bfc1","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f847f15b-ef8b-440c-9024-4d63fd11ed61","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c0d9fe39-5cea-49ad-8ea0-22567e35bfc1","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y": ...

# %%
projectsBoxplot(df, year=2015)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="15b8e12c-ca1a-4d02-bddc-523c181686ac">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="db773984-ac11-4d04-9b2a-74ce03181356"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("db773984-ac11-4d04-9b2a-74ce03181356");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("db773984-ac11-4d04-9b2a-74ce03181356");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'db773984-ac11-4d04-9b2a-74ce03181356' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9e9819cd-2fa0-4b7b-ac86-a11b6da35372":{"roots":{"references":[{"attributes":{"data_source":{"id":"221bdac8-c687-44ab-bc84-6cfdfa661705","type":"ColumnDataSource"},"glyph":{"id":"c9f049aa-d4a4-476f-b6b3-2a46f9e5e07e","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"71712389-1b2b-4706-8dff-729042619257","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"73575d54-644b-4f73-8ced-0ae15dd54f0b","type":"PanTool"},{"id":"840c05e5-77c7-4f89-b563-72b32c65c277","type":"WheelZoomTool"},{"id":"bd2f760e-ce6e-4d45-b0ce-51d116ee337d","type":"BoxZoomTool"},{"id":"3c378d8c-dcde-4f2b-b6e5-adbc1c4d6cac","type":"SaveTool"},{"id":"76b9e46a-307b-4fff-b0c2-efeae81c3734","type":"ResetTool"},{"id":"8fe76c77-a5f4-449b-bdff-e6798dccc8fb","type":"HelpTool"}]},"id":"45c14dc7-99da-49a4-990d-7ee066a4b81e","type":"Toolbar"},{"attributes":{"data_source":{"id":"a4272068-778c-4d5e-b536-377c3f9d7346","type":"ColumnDataSource"},"glyph":{"id":"f1e43872-94cf-47ec-850c-6930e91ab1c6","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"e0f65432-14b8-4c52-9977-1fb676ec9487","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"projType":"INTERNO"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[6.0],"label":[{"projType":"INTERNO"}],"line_alpha":[1.0],"line_color":["black"],"projType":["INTERNO"],"width":[0.8],"x":["INTERNO"],"y":[4.0]}},"id":"221bdac8-c687-44ab-bc84-6cfdfa661705","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"projType":"INTERNO"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[9.0],"label":[{"projType":"INTERNO"}],"line_alpha":[1.0],"line_color":["black"],"projType":["INTERNO"],"width":[0.8],"x":["INTERNO"],"y":[11.5]}},"id":"24f63794-b427-4645-a68a-b04dfd422207","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"projType":"EXTERNO"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":[{"projType":"EXTERNO"}],"line_alpha":[1.0],"line_color":["black"],"projType":["EXTERNO"],"width":[0.8],"x":["EXTERNO"],"y":[0.5]}},"id":"7016ab49-66d3-43d1-b220-d3f3dbb11afc","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"cac47347-61e2-4a9e-87ac-4316194706e0","type":"ColumnDataSource"},"glyph":{"id":"ec4caf35-6108-4ee1-9eec-869f08755091","type":"Segment"},"hover_glyph":null,"muted_glyph":null},"id":"7928b6f7-59d4-4759-b6c5-4d04c3d4504c","type":"GlyphRenderer"},{"attributes":{},"id":"e89a1a6a-b243-454b-a72f-e727add73feb","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"558e52ea-c14b-469e-b823-574f32dc324d","subtype":"Chart","type":"Plot"}},"id":"73575d54-644b-4f73-8ced-0ae15dd54f0b","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"projType":"INTERNO"},{"projType":"INTERNO"},{"projType":"INTERNO"},{"projType":"INTERNO"}],"projType":["INTERNO","INTERNO","INTERNO","INTERNO"],"x0s":["INTERNO:0.5","INTERNO:0.65","INTERNO:0.5","INTERNO:0.65"],"x1s":["INTERNO:0.5","INTERNO:0.35","INTERNO:0.5","INTERNO:0.35"],"y0s":[0,0,16.0,38.5],"y1s":[1.0,0,38.5,38.5]}},"id":"1c07878f-25b3-40c6-a002-3b07eb021f05","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7016ab49-66d3-43d1-b220-d3f3dbb11afc","type":"ColumnDataSource"},"glyph":{"id":"ed2044ba-fd9d-413a-aa47-bb3688adb995","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"dc678411-e589-4965-a1e4-981b3d4e79a8","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"goldenrod"},"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"18b7c4c8-13e3-48f ...

# %% [markdown]
# ## 6. Pelo menos dois gráficos de Correlação

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# %matplotlib inline

np.random.seed(int(datetime.now().day + datetime.now().second))

sns.set(color_codes=True)

df = pd.read_csv("pesquisadores.csv", sep=";")
df['totalProjetos'] = df.apply(lambda row: row['internos']+row['externos'],
  axis=1)

# %%
sns.lmplot(x="internos", y="externos", data=df, x_jitter=0.2, y_jitter=0.21, robust=False);

# %%
sns.lmplot(x="totalProjetos", y="coordenador", data=df, 
                  x_jitter=0.2, y_jitter=0.21, order=3);
